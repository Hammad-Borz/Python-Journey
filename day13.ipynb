# %% [markdown]
# # My First Jupyter Notebook
# Today I learned Variables and Printing

# %%
name = "Borz"
age = 18

# %%
print(name)
print(age)
# Out:
# Borz
# 18

# %%
for number in range(1, 7):
    print(number)
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
